# %% [markdown]
# # Read Inventory

# %%
dct_listofproducts={1001:{"productname":"Chocolate","quantity":"10","Discounted Price":"45","RATING OUT OF 5":"5","Cost Price":"50"},
 1002:{"productname":"Icecream","quantity":"15","Discounted Price":"120","RATING OUT OF 5":"4","Cost Price":"125"},
 1003:{"productname":"Biscuits","quantity":"2","Discounted Price":"22","RATING OUT OF 5":"4","Cost Price":"25"},
 1004:{"productname":"Toothbrush","quantity":"4","Discounted Price":"27","RATING OUT OF 5":"3","Cost Price":"30"},
 1005:{"productname":"Wafers","quantity":"5","Discounted Price":"28","RATING OUT OF 5":"4","Cost Price":"30"},
 1006:{"productname":"Toothpaste","quantity":"2","Discounted Price":"55","RATING OUT OF 5":"3","Cost Price":"60"},
 1007:{"productname":"Oats","quantity":"3","Discounted Price":"72","RATING OUT OF 5":"5","Cost Price":"75"},
 1008:{"productname":"Butter","quantity":"1","Discounted Price":"125","RATING OUT OF 5":"5","Cost Price":"130"},
 1009:{"productname":"Bread","quantity":"6","Discounted Price":"25","RATING OUT OF 5":"4","Cost Price":"30"},
 1010:{"productname":"Salt","quantity":"3","Discounted Price":"45","RATING OUT OF 5":"4","Cost Price":"50"},
 1011:{"productname":"Sugar","quantity":"4","Discounted Price":"32","RATING OUT OF 5":"5","Cost Price":"35"},
 1012:{"productname":"Detergent","quantity":"2","Discounted Price":"94","RATING OUT OF 5":"5","Cost Price":"100"},
 1013:{"productname":"Cheese","quantity":"1","Discounted Price":"146","RATING OUT OF 5":"5","Cost Price":"150"},
 1014:{"productname":"Pizzabase","quantity":"2","Discounted Price":"148","RATING OUT OF 5":"4","Cost Price":"150"},
 1015:{"productname":"Oregano","quantity":"3","Discounted Price":"195","RATING OUT OF 5":"4","Cost Price":"200"},
 1016:{"productname":"Chilliflakes","quantity":"4","Discounted Price":"155","RATING OUT OF 5":"5","Cost Price":"160"},
 1017:{"productname":"Sauce","quantity":"3","Discounted Price":"175","RATING OUT OF 5":"3","Cost Price":"180"},
 1018:{"productname":"Namkeen","quantity":"5","Discounted Price":"45","RATING OUT OF 5":"3","Cost Price":"50"},
 1019:{"productname":"Jaggrey","quantity":"3","Discounted Price":"75","RATING OUT OF 5":"4","Cost Price":"80"},
 1020:{"productname":"Tortila","quantity":"2","Discounted Price":"56","RATING OUT OF 5":"4","Cost Price":"60"},
 1021:{"productname":"Cornflakes","quantity":"6","Discounted Price":"295","RATING OUT OF 5":"4","Cost Price":"300"},
 1022:{"productname":"Jelly","quantity":"4","Discounted Price":"75","RATING OUT OF 5":"4","Cost Price":"80"},
 1023:{"productname":"Conditioner","quantity":"7","Discounted Price":"255","RATING OUT OF 5":"2","Cost Price":"260"},
 1024:{"productname":"ToiletPaper","quantity":"5","Discounted Price":"174","RATING OUT OF 5":"2","Cost Price":"180"},
 1025:{"productname":"Shampoo","quantity":"2","Discounted Price":"295","RATING OUT OF 5":"2","Cost Price":"300"},
 1026:{"productname":"Bodywash","quantity":"6","Discounted Price":"317","RATING OUT OF 5":"3","Cost Price":"320"},
 1027:{"productname":"Deodorant","quantity":"3","Discounted Price":"295","RATING OUT OF 5":"4","Cost Price":"300"},
 1028:{"productname":"Dry Fruits","quantity":"2","Discounted Price":"245","RATING OUT OF 5":"5","Cost Price":"250"},
 1029:{"productname":"Bulbs","quantity":"4","Discounted Price":"420","RATING OUT OF 5":"3","Cost Price":"450"},
 1030:{"productname":"Pickles","quantity":"5","Discounted Price":"120","RATING OUT OF 5":"5","Cost Price":"150"}}

# %% [markdown]
# # Import Libraries

# %%
import json
import time

# %%
json_ims= json.dumps(dct_listofproducts)

# %%
json_ims
# Out:
# '{"1001": {"productname": "Chocolate", "quantity": "10", "Discounted Price": "45", "RATING OUT OF 5": "5", "Cost Price": "50"}, "1002": {"productname": "Icecream", "quantity": "15", "Discounted Price": "120", "RATING OUT OF 5": "4", "Cost Price": "125"}, "1003": {"productname": "Biscuits", "quantity": "2", "Discounted Price": "22", "RATING OUT OF 5": "4", "Cost Price": "25"}, "1004": {"productname": "Toothbrush", "quantity": "4", "Discounted Price": "27", "RATING OUT OF 5": "3", "Cost Price": "30"}, "1005": {"productname": "Wafers", "quantity": "5", "Discounted Price": "28", "RATING OUT OF 5": "4", "Cost Price": "30"}, "1006": {"productname": "Toothpaste", "quantity": "2", "Discounted Price": "55", "RATING OUT OF 5": "3", "Cost Price": "60"}, "1007": {"productname": "Oats", "quantity": "3", "Discounted Price": "72", "RATING OUT OF 5": "5", "Cost Price": "75"}, "1008": {"productname": "Butter", "quantity": "1", "Discounted Price": "125", "RATING OUT OF 5": "5", "Cost Price": "130"}, "
# ...

# %% [markdown]
# # Adding Original Price and Purchase Time

# %%
for i in dct_listofproducts.keys(): 
    dct_listofproducts[i]["Cost Price"]=int(dct_listofproducts[i]["Cost Price"])
    dct_listofproducts[i]["quantity"]=int(dct_listofproducts[i]["quantity"])
    dct_listofproducts[i]["Original Price"]=dct_listofproducts[i]["Cost Price"]*dct_listofproducts[i]["quantity"]
    dct_listofproducts[i]["Purchase Time"]=time.ctime()
dct_listofproducts
# Out:
# {1001: {'productname': 'Chocolate',
#   'quantity': 10,
#   'Discounted Price': '45',
#   'RATING OUT OF 5': '5',
#   'Cost Price': 50,
#   'Original Price': 500,
#   'Purchase Time': 'Mon Sep  6 17:40:39 2021'},
#  1002: {'productname': 'Icecream',
#   'quantity': 15,
#   'Discounted Price': '120',
#   'RATING OUT OF 5': '4',
#   'Cost Price': 125,
#   'Original Price': 1875,
#   'Purchase Time': 'Mon Sep  6 17:40:39 2021'},
#  1003: {'productname': 'Biscuits',
#   'quantity': 2,
#   'Discounted Price': '22',
#   'RATING OUT OF 5': '4',
#   'Cost Price': 25,
#   'Original Price': 50,
#   'Purchase Time': 'Mon Sep  6 17:40:39 2021'},
#  1004: {'productname': 'Toothbrush',
#   'quantity': 4,
#   'Discounted Price': '27',
#   'RATING OUT OF 5': '3',
#   'Cost Price': 30,
#   'Original Price': 120,
#   'Purchase Time': 'Mon Sep  6 17:40:39 2021'},
#  1005: {'productname': 'Wafers',
#   'quantity': 5,
#   'Discounted Price': '28',
#   'RATING OUT OF 5': '4',
#   'Cost Price': 30,
# ...

# %%
with open("ims-priscilla.json", "w") as outfile:
    json.dump(dct_listofproducts, outfile)

# %%
fd=open("ims-priscilla.json","r")
prodtxt=fd.read()
prodtxt
# Out:
# '{"1001": {"productname": "Chocolate", "quantity": 10, "Discounted Price": "45", "RATING OUT OF 5": "5", "Cost Price": 50, "Original Price": 500, "Purchase Time": "Mon Sep  6 17:40:39 2021"}, "1002": {"productname": "Icecream", "quantity": 15, "Discounted Price": "120", "RATING OUT OF 5": "4", "Cost Price": 125, "Original Price": 1875, "Purchase Time": "Mon Sep  6 17:40:39 2021"}, "1003": {"productname": "Biscuits", "quantity": 2, "Discounted Price": "22", "RATING OUT OF 5": "4", "Cost Price": 25, "Original Price": 50, "Purchase Time": "Mon Sep  6 17:40:39 2021"}, "1004": {"productname": "Toothbrush", "quantity": 4, "Discounted Price": "27", "RATING OUT OF 5": "3", "Cost Price": 30, "Original Price": 120, "Purchase Time": "Mon Sep  6 17:40:39 2021"}, "1005": {"productname": "Wafers", "quantity": 5, "Discounted Price": "28", "RATING OUT OF 5": "4", "Cost Price": 30, "Original Price": 150, "Purchase Time": "Mon Sep  6 17:40:39 2021"}, "1006": {"productname": "Toothpaste", "quantity": 2
# ...

# %%
a=prodtxt.split('},')

# %%
a
# Out:
# ['{"1001": {"productname": "Chocolate", "quantity": 10, "Discounted Price": "45", "RATING OUT OF 5": "5", "Cost Price": 50, "Original Price": 500, "Purchase Time": "Mon Sep  6 17:40:39 2021"',
#  ' "1002": {"productname": "Icecream", "quantity": 15, "Discounted Price": "120", "RATING OUT OF 5": "4", "Cost Price": 125, "Original Price": 1875, "Purchase Time": "Mon Sep  6 17:40:39 2021"',
#  ' "1003": {"productname": "Biscuits", "quantity": 2, "Discounted Price": "22", "RATING OUT OF 5": "4", "Cost Price": 25, "Original Price": 50, "Purchase Time": "Mon Sep  6 17:40:39 2021"',
#  ' "1004": {"productname": "Toothbrush", "quantity": 4, "Discounted Price": "27", "RATING OUT OF 5": "3", "Cost Price": 30, "Original Price": 120, "Purchase Time": "Mon Sep  6 17:40:39 2021"',
#  ' "1005": {"productname": "Wafers", "quantity": 5, "Discounted Price": "28", "RATING OUT OF 5": "4", "Cost Price": 30, "Original Price": 150, "Purchase Time": "Mon Sep  6 17:40:39 2021"',
# ...

# %%
ims=json.loads(prodtxt)

# %%
ims
# Out:
# {'1001': {'productname': 'Chocolate',
#   'quantity': 10,
#   'Discounted Price': '45',
#   'RATING OUT OF 5': '5',
#   'Cost Price': 50,
#   'Original Price': 500,
#   'Purchase Time': 'Mon Sep  6 17:40:39 2021'},
#  '1002': {'productname': 'Icecream',
#   'quantity': 15,
#   'Discounted Price': '120',
#   'RATING OUT OF 5': '4',
#   'Cost Price': 125,
#   'Original Price': 1875,
#   'Purchase Time': 'Mon Sep  6 17:40:39 2021'},
#  '1003': {'productname': 'Biscuits',
#   'quantity': 2,
#   'Discounted Price': '22',
#   'RATING OUT OF 5': '4',
#   'Cost Price': 25,
#   'Original Price': 50,
#   'Purchase Time': 'Mon Sep  6 17:40:39 2021'},
#  '1004': {'productname': 'Toothbrush',
#   'quantity': 4,
#   'Discounted Price': '27',
#   'RATING OUT OF 5': '3',
#   'Cost Price': 30,
#   'Original Price': 120,
#   'Purchase Time': 'Mon Sep  6 17:40:39 2021'},
#  '1005': {'productname': 'Wafers',
#   'quantity': 5,
#   'Discounted Price': '28',
#   'RATING OUT OF 5': '4',
# ...

# %%
ui_name=str(input("enter your name: "))          
ui_prod=str(input("enter the product id: "))
ui_quant=int(input("enter the quantity: "))

for i in ims:
    
    if(str(ui_prod)== i):
        print("Product: ", ims[ui_prod]['productname'])
        print("Price: ", ims[ui_prod]['Cost Price'])
        print("Billing Amount: ", ims[ui_prod]['Cost Price'] * ui_quant)
        ims[ui_prod]['quantity'] = ims[ui_prod]['quantity'] - ui_quant
        print("***********************")
        print("name of the customer",ui_name)
        print("Prod Id: ",i)
        print("Name:" ,ims[i]['productname'])
        print("Original Price:",ims[i]['Original Price'])
        print("Discounted Price:",ims[i]['Discounted Price'])
        print("-------------------------------")
        print("Amount",int(ims[i]['Discounted Price']) * ui_quant)
        print("-------------------------------")
# Out:
# enter your name: Priscilla
# enter the product id: 1016
# enter the quantity: 1
# Product:  Chilliflakes
# Price:  160
# Billing Amount:  160
# ***********************
# name of the customer Priscilla
# Prod Id:  1016
# Name: Chilliflakes
# Original Price: 640
# Discounted Price: 155
# -------------------------------
# Amount 155
# -------------------------------

# %%
js = json.dumps(ims)

fd = open("ims-priscilla.json",'w')
fd.write(js)
fd.close()

# %%
ims
# Out:
# {'1001': {'productname': 'Chocolate',
#   'quantity': 10,
#   'Discounted Price': '45',
#   'RATING OUT OF 5': '5',
#   'Cost Price': 50,
#   'Original Price': 500,
#   'Purchase Time': 'Mon Sep  6 17:40:39 2021'},
#  '1002': {'productname': 'Icecream',
#   'quantity': 15,
#   'Discounted Price': '120',
#   'RATING OUT OF 5': '4',
#   'Cost Price': 125,
#   'Original Price': 1875,
#   'Purchase Time': 'Mon Sep  6 17:40:39 2021'},
#  '1003': {'productname': 'Biscuits',
#   'quantity': 2,
#   'Discounted Price': '22',
#   'RATING OUT OF 5': '4',
#   'Cost Price': 25,
#   'Original Price': 50,
#   'Purchase Time': 'Mon Sep  6 17:40:39 2021'},
#  '1004': {'productname': 'Toothbrush',
#   'quantity': 4,
#   'Discounted Price': '27',
#   'RATING OUT OF 5': '3',
#   'Cost Price': 30,
#   'Original Price': 120,
#   'Purchase Time': 'Mon Sep  6 17:40:39 2021'},
#  '1005': {'productname': 'Wafers',
#   'quantity': 5,
#   'Discounted Price': '28',
#   'RATING OUT OF 5': '4',
# ...

# %%
type(ims)
# Out:
# dict

# %%
ui_prod  = str(input("Enter the product_Id: "))
ui_quant = int(input("Enter the quantity: "))
for i in ims.keys():
    if ui_quant>=10:
        discount=5/100
    else:
        discount=0
    
    if ui_prod in i:
        ims[ui_prod] = {'productname':ims[ui_prod]['productname'],'quantity' : ui_quant,'RATING OUT OF 5': ims[ui_prod]['RATING OUT OF 5'],'Cost Price': ims[ui_prod]['Cost Price'],'Original Price': ims[ui_prod]['Cost Price'] * ui_quant,'Purchase Time': ims[ui_prod]['Purchase Time'],'Discounted Price': ims[ui_prod]['Original Price']-ims[ui_prod]['Original Price']*discount}
ims
# Out:
# Enter the product_Id: 1018
# Enter the quantity: 1
# {'1001': {'productname': 'Chocolate',
#   'quantity': 10,
#   'Discounted Price': '45',
#   'RATING OUT OF 5': '5',
#   'Cost Price': 50,
#   'Original Price': 500,
#   'Purchase Time': 'Mon Sep  6 17:40:39 2021'},
#  '1002': {'productname': 'Icecream',
#   'quantity': 15,
#   'Discounted Price': '120',
#   'RATING OUT OF 5': '4',
#   'Cost Price': 125,
#   'Original Price': 1875,
#   'Purchase Time': 'Mon Sep  6 17:40:39 2021'},
#  '1003': {'productname': 'Biscuits',
#   'quantity': 2,
#   'Discounted Price': '22',
#   'RATING OUT OF 5': '4',
#   'Cost Price': 25,
#   'Original Price': 50,
#   'Purchase Time': 'Mon Sep  6 17:40:39 2021'},
#  '1004': {'productname': 'Toothbrush',
#   'quantity': 4,
#   'Discounted Price': '27',
#   'RATING OUT OF 5': '3',
#   'Cost Price': 30,
#   'Original Price': 120,
#   'Purchase Time': 'Mon Sep  6 17:40:39 2021'},
#  '1005': {'productname': 'Wafers',
#   'quantity': 5,
# ...

# %% [markdown]
# # Output sales data to json

# %%
with open("sales.json", "w") as outfile:
    json.dump(ims, outfile)
